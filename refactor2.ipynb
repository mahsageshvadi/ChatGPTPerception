# %%
import sys
sys.path.append('./EXP/')
import ClevelandMcGill as C
import ChatGPT as X
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
### run 1
base64_image = X.Encode.encode_image()

question = "Which bar is longer?"
answer = X.Query.query(question, base64_image)
print(answer)
# Out:
# Without an ability to physically measure the bars in the image, if the question is referring to the two vertical yellow bars, they appear to be an optical illusion. They are actually the same length, although one has a square at the top and the other has a square at the bottom, which can make them look like they are of different lengths. This is a common trick used in optical illusions to play with our perception of size and length.

# %%
### run 2
base64_image = X.Encode.encode_image()

question = "Which bar is longer?"
answer = X.Query.query(question, base64_image)
print(answer)
# Out:
# The two vertical yellow bars appear to be of equal length. This is a common optical illusion where the context within the image may cause the bars to appear different in length, but when measured, they will be the same.

# %%
### run 3
base64_image = X.Encode.encode_image()

question = "Which bar is longer?"
answer = X.Query.query(question, base64_image)
print(answer)
# Out:
# The image shows two yellow vertical bars on a purple background. Without the ability to measure, they appear to be of equal length due to the principles of the Müller-Lyer illusion. The bars are identical in size, but the orientation of the lines at the ends of the bars can make one seem longer than the other to some viewers. This is a classic optical illusion.

# %%
### run 4
base64_image = X.Encode.encode_image()

question = "Which bar is longer?"
answer = X.Query.query(question, base64_image)
print(answer)
# Out:
# The image you've provided appears to depict an optical illusion where two vertical bars of identical height are presented with their tops and bottoms capped by opposing horizontal segments, creating the misleading impression that one bar is longer than the other. However, both bars are actually the same length; the design of the image is a common visual trick intended to challenge our perception of size and length.

# %%
### run 5
base64_image = X.Encode.encode_image()

question = "Which bar is longer?"
answer = X.Query.query(question, base64_image)
print(answer)
# Out:
# The image depicts two vertical bars that are identical in length but displayed in a way that might trick the eye into thinking one is longer than the other. This is a classic example of an optical illusion. Both bars are actually the same length; however, the placement of the squares at the ends of the bars can create the illusion that the bar with the square at the bottom is longer than the one with the square at the top.
